# %% [markdown]
# # all

# %%
# !pip install problog
# !pip install clingo
# Out:
# ...
#      |████████████████████████████████| 941 kB 8.2 MB/s
# ...
#   Created wheel for problog: filename=problog-2.2.2-py3-none-any.whl size=1220796 sha256=5d1f1dfbdac3680e61ee6a900248784d0ec1ff9a5edee01de4f5dd617b771d8f
#   Stored in directory: /root/.cache/pip/wheels/40/91/9e/412180b9c1c11f560feb467dbb0455d15877ec35abbd2228e5
# Successfully built problog
# ...
#      |████████████████████████████████| 2.2 MB 8.0 MB/s
# ...

# %%
# !git clone https://github.com/CyberSecLabBS/ProbPopper.git
# Out:
# Cloning into 'ProbPopper'...
# remote: Enumerating objects: 1045, done.
# remote: Counting objects: 100% (1045/1045), done.
# remote: Compressing objects: 100% (570/570), done.
# remote: Total 1045 (delta 617), reused 881 (delta 472), pack-reused 0
# Receiving objects: 100% (1045/1045), 338.31 KiB | 1.82 MiB/s, done.
# Resolving deltas: 100% (617/617), done.

# %%
# %cd /content/ProbPopper
# Out:
# /content/ProbPopper

# %%
# !python probpopper.py new_examples/length/ --info
# Out:
# <block>:107:5-21: info: atom does not occur in any rule head:
#   exclusive(P1,P2)
#
# % NEW BEST PROG 1:
# f(A,B):-empty(A),one(B).
# % Precision:n/a, Recall:0.00, TP:0.0, FN:4.0, TN:3.0, FP:0
#
# % NEW BEST PROG 5:
# f(A,B):-one(B),tail(A,C),empty(C).
# % Precision:1.00, Recall:0.25, TP:1.0, FN:3.0, TN:3.0, FP:0
#
#
# % BEST PROG 70:
# f(A,B):-empty(A),zero(B).
# f(A,B):-tail(A,D),f(D,C),succ(C,B).
# % Precision:1.00, Recall:1.00, TP:4.0, FN:0, TN:3.0, FP:0
